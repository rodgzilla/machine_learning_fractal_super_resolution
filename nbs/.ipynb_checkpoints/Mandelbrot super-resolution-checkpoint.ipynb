# %% [markdown]
# # Imports

# %%
# %matplotlib inline

from scipy.misc  import imresize

from keras.preprocessing import image
from keras.models        import Model
from keras.layers        import Input
from keras.layers        import Add
from keras.layers        import Convolution2D
from keras.layers        import Deconvolution2D
from keras.layers        import BatchNormalization
from keras.layers        import Activation
from keras.layers        import Convolution2DTranspose
from keras.layers        import UpSampling2D
from keras.optimizers    import Adam
from keras.callbacks     import ModelCheckpoint
from keras.callbacks     import LearningRateScheduler

import keras.backend     as K
import numpy             as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
def limit_mem():
    cfg                          = K.tf.ConfigProto()
    cfg.gpu_options.allow_growth = True
    K.set_session(K.tf.Session(config = cfg))
limit_mem()

# %% [markdown]
# # Definitions and helper functions
#
# Path and constant definitions

# %%
image_folder   = '../../data/fractal_zooms/'
batch_size     = 4
preprocess     = lambda x: (x - 127.5) / 127.5
small_shape    = (128, 192)
big_shape      = (256, 384)
epochs         = 100
start_lr       = 1e-3
end_lr         = 1e-5
learning_rates = np.linspace(start_lr, end_lr, epochs)

# %% [markdown]
# A small helper function to compare two sets of images side by side.

# %%
def visualize(array_1, array_2, nb_row):
    plt.figure(figsize = (17, 17))
    for i in range(nb_row):
        plt.subplot(nb_row, 2, 2 * i + 1)
        plt.imshow(array_1[i].squeeze(), cmap = 'gray')
        plt.subplot(nb_row, 2, 2 * i + 2)
        plt.imshow(array_2[i].squeeze(), cmap = 'gray')

# %% [markdown]
# We use an `ImageDataGenerator` to load batch of images from the disk. We also create a custom wrapper to generate image couples of the form (small_resolution_image, high_resolution_image).

# %%
generator       = image.ImageDataGenerator(preprocessing_function = preprocess)
flow_parameters = {
    'class_mode' : None,
    'target_size': big_shape,
    'color_mode' : 'grayscale',
    'batch_size' : batch_size
}
train_flow = generator.flow_from_directory(directory = image_folder + 'train/', **flow_parameters)
valid_flow = generator.flow_from_directory(directory = image_folder + 'test/', **flow_parameters)
# Out:
# Found 45000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.

# %%
def data_generator(flow, interp = 'nearest'):
    while True:
        output_images = next(flow)
        resize_image  = [imresize(output_images[i].squeeze(), small_shape, interp = interp) for i in range(output_images.shape[0])]
        input_images  = np.expand_dims(np.stack(resize_image), -1)
        
        yield (input_images, output_images)

# %% [markdown]
# Image loading and visualization test.

# %%
train_data_gen            = data_generator(train_flow)
valid_data_gen            = data_generator(valid_flow)
input_array, output_array = next(train_data_gen)
visualize(input_array, output_array, min(5, batch_size))

# %% [markdown]
# # Model definition
#
# ## Callbacks creation
#
# ### Model checkpoint callback
#
# Creation of the model checkpoint callback.

# %%
checkpoint_callback = ModelCheckpoint('../models/super_resolution.epoch_{epoch:02d}.h5', period = 40)

# %% [markdown]
# ## Learning rate annealing callback

# %%
def schedule(epoch):
    return learning_rates[epoch]

learning_rate_callback = LearningRateScheduler(schedule)

# %% [markdown]
# ## Architecture
#
# The architecture of the network comes from the article [Perceptual Losses for Real-Time Style Transfer and Super-Resolution](https://arxiv.org/abs/1603.08155). In this first example, a simple mean squared error on the pixel values is used in place of the perceptual loss. Another network in this repository will contain further exploration of the perceptual loss applied to this problem.

# %%
def convolution_block(inp, filter_size = 3, nb_filters = 64, activation = True):
    x = Convolution2D(nb_filters, (filter_size, filter_size), strides = (1, 1), padding = 'same')(inp)
    x = BatchNormalization()(x)
    x = Activation('relu')(x) if activation else x
    
    return x

# %%
def residual_block(inp, nb_filders = 64):
    x = convolution_block(inp, nb_filders)
    x = convolution_block(x  , nb_filders, activation = False)
    x = Add()([inp, x])
    
    return x

# %%
def deconvolution_block(inp, nb_filters = 64):
    x = Convolution2DTranspose(nb_filters, (3, 3), strides = (2, 2), padding = 'same')(inp)
    x = BatchNormalization()(x)
    
    return x

# %%
def upsampling_block(inp, nb_filter = 64):
    x = UpSampling2D()(inp)
    x = Convolution2D(nb_filter, (3, 3), strides = (1, 1), padding = 'same')(x)
    x = BatchNormalization()(x)
    
    return x

# %%
def create_model_deconvolution(input_shape):
    inp = Input(shape = input_shape + (1,))
    x   = convolution_block(inp, filter_size = 9, nb_filters = 64)
    for _ in range(4):
        x = residual_block(x)
    x     = deconvolution_block(x)
    x     = Convolution2D(1, (9, 9), strides = (1, 1), padding = 'same')(x)
    x     = Activation('tanh')(x)
    model = Model(inp, x)

    return model

# %%
def create_model_upsampling(input_shape):
    inp = Input(shape = input_shape + (1,))
    x   = convolution_block(inp, filter_size = 9, nb_filters = 64)
    for _ in range(4):
        x = residual_block(x)
    x     = upsampling_block(x)
    x     = Convolution2D(1, (9, 9), strides = (1, 1), padding = 'same')(x)
    x     = Activation('tanh')(x)
    model = Model(inp, x)

    return model

# %%
model = create_model_deconvolution(small_shape)
# model = create_model_upsampling(small_shape)
model.compile(optimizer = Adam(1e-3), loss = 'mse')
# model.summary()

# %%
fit_parameters = {
    'epochs'           : 100,
    'generator'        : train_data_gen,
    'steps_per_epoch'  : 10,
    'validation_data'  : valid_data_gen,
    'validation_steps' : 10,
    'callbacks'        : [checkpoint_callback, learning_rate_callback],
    'verbose'          : 2
}

# %%
model.fit_generator(**fit_parameters)
# Out:
# /home/rodgzilla/Documents/machine_learning/keras/keras/backend/tensorflow_backend.py:2252: UserWarning: Expected no kwargs, you passed 1
# kwargs passed to function are ignored with Tensorflow backend
#   warnings.warn('\n'.join(msg))
# Epoch 1/100
# 38s - loss: 0.7425 - val_loss: 2.9917
# Epoch 2/100
# 26s - loss: 0.4301 - val_loss: 2.9505
# Epoch 3/100
# 26s - loss: 0.3063 - val_loss: 2.3125
# Epoch 4/100
# 26s - loss: 0.2838 - val_loss: 2.2206
# Epoch 5/100
# 26s - loss: 0.2693 - val_loss: 2.6109
# Epoch 6/100
# 26s - loss: 0.2411 - val_loss: 1.5680
# Epoch 7/100
# 27s - loss: 0.2268 - val_loss: 1.5708
# Epoch 8/100
# 26s - loss: 0.1649 - val_loss: 0.8040
# Epoch 9/100
# 26s - loss: 0.0949 - val_loss: 0.5494
# Epoch 10/100
# 26s - loss: 0.0617 - val_loss: 0.1010
# Epoch 11/100
# 26s - loss: 0.0533 - val_loss: 0.1232
# Epoch 12/100
# 26s - loss: 0.0604 - val_loss: 0.1448
# Epoch 13/100
# 26s - loss: 0.0498 - val_loss: 0.4081
# Epoch 14/100
# 26s - loss: 0.0498 - val_loss: 0.1167
# Epoch 15/100
# 26s - loss: 0.0647 - val_loss: 0.0703
# Epoch 16/100
# 26s - loss: 0.0505 - val_loss: 0.1123
# Epoch 17/100
# 26s - loss: 0.0515 - val_loss: 0.0595
# Epoch 18/100
# 26s - loss: 0.0573 - val_loss: 0.0669
# Epoch 19/100
# 26s - loss: 0.0467 - val_loss: 0.0777
# Epoch 20/100
# 26s - loss: 0.0423 - val_loss: 0.0941
# Epoch 21/100
# 26s - loss: 0.0557 - val_loss: 0.1165
# Epoch 22/100
# 26s - loss: 0.0731 - val_loss: 0.1054
# Epoch 23/100
# 26s - loss: 0.0542 - val_loss: 0.0485
# Epoch 24/100
# 26s - loss: 0.0363 - val_loss: 0.0825
# Epoch 25/100
# 26s - loss: 0.0393 - val_loss: 0.0557
# Epoch 26/100
# 26s - loss: 0.0501 - val_loss: 0.0461
# Epoch 27/100
# 27s - loss: 0.0481 - val_loss: 0.1099
# Epoch 28/100
# 26s - loss: 0.0532 - val_loss: 0.0430
# Epoch 29/100
# 26s - loss: 0.0417 - val_loss: 0.0755
# Epoch 30/100
# 26s - loss: 0.0447 - val_loss: 0.0732
# Epoch 31/100
# 26s - loss: 0.0531 - val_loss: 0.0431
# Epoch 32/100
# 26s - loss: 0.0369 - val_loss: 0.0178
# Epoch 33/100
# 26s - loss: 0.0450 - val_loss: 0.0285
# Epoch 34/100
# 26s - loss: 0.0507 - val_loss: 0.0720
# Epoch 35/100
# 26s - loss: 0.0453 - val_loss: 0.0438
# Epoch 36/100
# 26s - loss: 0.0340 - val_loss: 0.0418
# Epoch 37/100
# 26s - loss: 0.0492 - val_loss: 0.0305
# Epoch 38/100
# 26s - loss: 0.0537 - val_loss: 0.0796
# Epoch 39/100
# 26s - loss: 0.0470 - val_loss: 0.0544
# Epoch 40/100
# 27s - loss: 0.0475 - val_loss: 0.0377
# Epoch 41/100
# 26s - loss: 0.0382 - val_loss: 0.0494
# Epoch 42/100
# 26s - loss: 0.0346 - val_loss: 0.0283
# Epoch 43/100
# 26s - loss: 0.0433 - val_loss: 0.0451
# Epoch 44/100
# 26s - loss: 0.0408 - val_loss: 0.0396
# Epoch 45/100
# 26s - loss: 0.0295 - val_loss: 0.0595
# Epoch 46/100
# 26s - loss: 0.0513 - val_loss: 0.0390
# Epoch 47/100
# 26s - loss: 0.0639 - val_loss: 0.0645
# Epoch 48/100
# 26s - loss: 0.0317 - val_loss: 0.0477
# Epoch 49/100
# 26s - loss: 0.0530 - val_loss: 0.0296
# Epoch 50/100
# 27s - loss: 0.0491 - val_loss: 0.0732
# Epoch 51/100
# 26s - loss: 0.0389 - val_loss: 0.0369
# Epoch 52/100
# 26s - loss: 0.0274 - val_loss: 0.0415
# Epoch 53/100
# 26s - loss: 0.0451 - val_loss: 0.0587
# Epoch 54/100
# 26s - loss: 0.0372 - val_loss: 0.0310
# Epoch 55/100
# 26s - loss: 0.0405 - val_loss: 0.0395
# Epoch 56/100
# 26s - loss: 0.0291 - val_loss: 0.0313
# Epoch 57/100
# 26s - loss: 0.0557 - val_loss: 0.0467
# Epoch 58/100
# 26s - loss: 0.0272 - val_loss: 0.0159
# Epoch 59/100
# 26s - loss: 0.0310 - val_loss: 0.0165
# Epoch 60/100
# 25s - loss: 0.0351 - val_loss: 0.0354
# Epoch 61/100
# 26s - loss: 0.0429 - val_loss: 0.0316
# Epoch 62/100
# 26s - loss: 0.0322 - val_loss: 0.0198
# Epoch 63/100
# 26s - loss: 0.0207 - val_loss: 0.0306
# Epoch 64/100
# 26s - loss: 0.0345 - val_loss: 0.0515
# Epoch 65/100
# 26s - loss: 0.0654 - val_loss: 0.0165
# Epoch 66/100
# 26s - loss: 0.0355 - val_loss: 0.0493
# Epoch 67/100
# 25s - loss: 0.0422 - val_loss: 0.0381
# Epoch 68/100
# 26s - loss: 0.0406 - val_loss: 0.0433
# Epoch 69/100
# 26s - loss: 0.0304 - val_loss: 0.0296
# Epoch 70/100
# 26s - loss: 0.0467 - val_loss: 0.0197
# Epoch 71/100
# 26s - loss: 0.0273 - val_loss: 0.0288
# Epoch 72/100
# 26s - loss: 0.0262 - val_loss: 0.0132
# Epoch 73/100
# 26s - loss: 0.0184 - val_loss: 0.0295
# Epoch 74/100
# 26s - loss: 0.0195 - val_loss: 0.0244
# Epoch 75/100
# 26s - loss: 0.0140 - val_loss: 0.0197
# Epoch 76/100
# 26s - loss: 0.0127 - val_loss: 0.0188
# Epoch 77/100
# 26s - loss: 0.0241 - val_loss: 0.0232
# Epoch 78/100
# 25s - loss: 0.0257 - val_loss: 0.0368
# Epoch 79/100
# 26s - loss: 0.0212 - val_loss: 0.0351
# Epoch 80/100
# 27s - loss: 0.0205 - val_loss: 0.0143
# Epoch 81/100
# 26s - loss: 0.0265 - val_loss: 0.0506
# Epoch 82/100
# 26s - loss: 0.0218 - val_loss: 0.0222
# Epoch 83/100
# 26s - loss: 0.0157 - val_loss: 0.0221
# Epoch 84/100
# 26s - loss: 0.0211 - val_loss: 0.0317
# Epoch 85/100
# 26s - loss: 0.0191 - val_loss: 0.0204
# Epoch 86/100
# 25s - loss: 0.0175 - val_loss: 0.0260
# Epoch 87/100
# 26s - loss: 0.0152 - val_loss: 0.0201
# Epoch 88/100
# 26s - loss: 0.0155 - val_loss: 0.0175
# Epoch 89/100
# 25s - loss: 0.0179 - val_loss: 0.0169
# Epoch 90/100
# 26s - loss: 0.0233 - val_loss: 0.0373
# Epoch 91/100
# 26s - loss: 0.0295 - val_loss: 0.0219
# Epoch 92/100
# 25s - loss: 0.0354 - val_loss: 0.0238
# Epoch 93/100
# 26s - loss: 0.0132 - val_loss: 0.0324
# Epoch 94/100
# 26s - loss: 0.0155 - val_loss: 0.0283
# Epoch 95/100
# 26s - loss: 0.0281 - val_loss: 0.0138
# Epoch 96/100
# 26s - loss: 0.0157 - val_loss: 0.0119
# Epoch 97/100
# 26s - loss: 0.0155 - val_loss: 0.0141
# Epoch 98/100
# 26s - loss: 0.0148 - val_loss: 0.0117
# Epoch 99/100
# 26s - loss: 0.0138 - val_loss: 0.0137
# Epoch 100/100
# 26s - loss: 0.0214 - val_loss: 0.0133

# %%
small_img, big_img = next(valid_data_gen)
big_img_pred       = model.predict(small_img, batch_size = batch_size)
visualize(big_img_pred, big_img, batch_size)
# Out:
# /home/rodgzilla/Documents/machine_learning/keras/keras/backend/tensorflow_backend.py:2252: UserWarning: Expected no kwargs, you passed 1
# kwargs passed to function are ignored with Tensorflow backend
#   warnings.warn('\n'.join(msg))

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 128, 192, 1)   0
# ____________________________________________________________________________________________________
# conv2d_1 (Conv2D)                (None, 128, 192, 64)  5248        input_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_1 (BatchNorm (None, 128, 192, 64)  256         conv2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 128, 192, 64)  0           batch_normalization_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2 (Conv2D)                (None, 128, 192, 64)  16777280    activation_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_2 (BatchNorm (None, 128, 192, 64)  256         conv2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 128, 192, 64)  0           batch_normalization_2[0][0]
# ____________________________________________________________________________________________________
# conv2d_3 (Conv2D)                (None, 128, 192, 64)  16777280    activation_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_3 (BatchNorm (None, 128, 192, 64)  256         conv2d_3[0][0]
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 128, 192, 64)  0           activation_1[0][0]
#                                                                    batch_normalization_3[0][0]
# ____________________________________________________________________________________________________
# conv2d_4 (Conv2D)                (None, 128, 192, 64)  16777280    add_1[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_4 (BatchNorm (None, 128, 192, 64)  256         conv2d_4[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 128, 192, 64)  0           batch_normalization_4[0][0]
# ____________________________________________________________________________________________________
# conv2d_5 (Conv2D)                (None, 128, 192, 64)  16777280    activation_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_5 (BatchNorm (None, 128, 192, 64)  256         conv2d_5[0][0]
# ____________________________________________________________________________________________________
# add_2 (Add)                      (None, 128, 192, 64)  0           add_1[0][0]
#                                                                    batch_normalization_5[0][0]
# ____________________________________________________________________________________________________
# conv2d_6 (Conv2D)                (None, 128, 192, 64)  16777280    add_2[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_6 (BatchNorm (None, 128, 192, 64)  256         conv2d_6[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 128, 192, 64)  0           batch_normalization_6[0][0]
# ____________________________________________________________________________________________________
# conv2d_7 (Conv2D)                (None, 128, 192, 64)  16777280    activation_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_7 (BatchNorm (None, 128, 192, 64)  256         conv2d_7[0][0]
# ____________________________________________________________________________________________________
# add_3 (Add)                      (None, 128, 192, 64)  0           add_2[0][0]
#                                                                    batch_normalization_7[0][0]
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 128, 192, 64)  16777280    add_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_8 (BatchNorm (None, 128, 192, 64)  256         conv2d_8[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 128, 192, 64)  0           batch_normalization_8[0][0]
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 128, 192, 64)  16777280    activation_5[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_9 (BatchNorm (None, 128, 192, 64)  256         conv2d_9[0][0]
# ____________________________________________________________________________________________________
# add_4 (Add)                      (None, 128, 192, 64)  0           add_3[0][0]
#                                                                    batch_normalization_9[0][0]
# ____________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTransp (None, 256, 384, 64)  36928       add_4[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_10 (BatchNor (None, 256, 384, 64)  256         conv2d_transpose_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 256, 384, 1)   5185        batch_normalization_10[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 256, 384, 1)   0           conv2d_10[0][0]
# ====================================================================================================
# Total params: 134,268,161
# Trainable params: 134,266,881
# Non-trainable params: 1,280
# ____________________________________________________________________________________________________
